# %% [markdown]
# Hi, I'm a Data Science enthusiast, who started using  kaggle recently.
#
# First, I would like to thanks the Kaggle team and the Kagglers for conducting this survey.
# I am feeling quite good that I was also participate in kaggle survey and now I am going to analyze the same data.
# Kudos!

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/kaggle-survey-2019/questions_only.csv
# /kaggle/input/kaggle-survey-2019/multiple_choice_responses.csv
# /kaggle/input/kaggle-survey-2019/other_text_responses.csv
# /kaggle/input/kaggle-survey-2019/survey_schema.csv

# %% [markdown]
# # Data Scientists in 2019 - Kaggle Survey

# %% [markdown]
# # Introduction
# We will analyze the dataset 2018 Kaggle ML & DS Survey Challenge with answers provided by the respondents to the survey of Kaggle users in 2019.
# This survey received 19,717 usable respondents from 171 countries and territories. If a country or territory received less than 50 respondents, we grouped them into a group named “Other” for anonymity.
#
# Survey Detail - This year, as in 2017 and 2018, we set out to conduct an industry-wide survey that presents a truly comprehensive view of the state of data science and machine learning. The survey was live for three weeks in October, and after cleaning the data we finished with 19,717 responses!

# %% [markdown]
# # Prepare the data analysis
# Before starting the analysis, we need to make few preparation: load the packages, load and inspect the data.

# %% [markdown]
# # Load packages
# We load the packages used for the analysis.

# %%
import sys
import os
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline

# %% [markdown]
# # Load the data
# Let's see first what data files do we have in the root directo

# %% [markdown]
# There are four files with the results of the survey.
# 1 - multipleChoiceResponses.csv - Multiple choice single response questions fit into individual columns whereas multiple choice multiple response questions were split into multiple columns. Text responses were encoded to protect user privacy and countries with fewer than 50 respondents were grouped into the category "other".
# 9
# 2- Surveyschema.csv - Survey schema describing which questions were presented to which respondents. In general, respondents with more experience were asked more questions than respondents with less experience.
#
# 3 - other_text_responses.csv - If "Other" is selected there is also an option to provide a text response. These text responses were separated and shuffled to protect user privacy.
#
# 4 - questions_only.csv - The list of questions from the 2019 Kaggle Data Science and Machine Learning Survey

# %% [markdown]
# Let us start our analysis by looking at the data from from multipleChoiceResponses.csv file

# %%
os.listdir("../input")
# Out:
# ['kaggle-survey-2019']

# %%
#Importing the 2019 Dataset
df_2019 = pd.read_csv('../input/kaggle-survey-2019/multiple_choice_responses.csv')
df_2019.columns = df_2019.iloc[0]
df_2019=df_2019.drop([0])
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2019.head(2)
# Out:
# 0 Duration (in seconds) What is your age (# years)?  \
# 1                   510                       22-24
# 2                   423                       40-44
#
# 0 What is your gender? - Selected Choice  \
# 1                                   Male
# 2                                   Male
#
# 0 What is your gender? - Prefer to self-describe - Text  \
# 1                                                 -1
# 2                                                 -1
#
# 0 In which country do you currently reside?  \
# 1                                    France
# 2                                     India
#
# 0 What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  \
# 1                                    Master’s degree
# 2                                Professional degree
#
# 0 Select the title most similar to your current role (or most recent title if retired): - Selected Choice  \
# ...

# %%
import matplotlib.pyplot as plt
nationality=df_2019['In which country do you currently reside?'].value_counts()
print(nationality)
# Out:
# India                                                   4786
# United States of America                                3085
# Other                                                   1054
# Brazil                                                   728
# Japan                                                    673
# Russia                                                   626
# China                                                    574
# Germany                                                  531
# United Kingdom of Great Britain and Northern Ireland     482
# Canada                                                   450
# Spain                                                    399
# Nigeria                                                  395
# France                                                   387
# Taiwan                                                   301
# Turkey                                                   288
# ...

# %% [markdown]
# # Country
# The largest number of responses to survey were from India and Us. People from India participate in survey mostly.

# %%
plt.figure(figsize=(20,60))
ax=df_2019['In which country do you currently reside?'].value_counts()[:59].plot.barh(width=0.6,color=sns.color_palette('Set2',25))
plt.gca().invert_yaxis()
plt.title('Country')
plt.show()

# %% [markdown]
# # AGE -
# As picture speaks itself Millennials dominate data science, with 25-29 year olds being the most common age bracket.

# %%
df_2019.iloc[1:, :]['What is your age (# years)?'].value_counts().plot(kind='bar', figsize=(20, 8))
plt.xlabel('Age Groups')
plt.ylabel('Count')
plt.title('Age Groups Distribution')
plt.show()

# %% [markdown]
# # GENDER -
# Its claerly visible that Males occupied the market in Data Scientist field.
#
# Girls need to pull socks and contribute more. Ha ha ...

# %%
df_2019.iloc[1:, :]['What is your gender? - Selected Choice'].value_counts().plot(kind='bar', figsize=(20, 8), color=['blue', 'red', 'green', 'cyan'])
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Sex s Distribution')
plt.show()

# %% [markdown]
# # EDUCATION -
#
# Based on education can say The data scientist community is highly educated. Looking at only employed data scientists, over 70% of respondents have a degree above a bachelor’s degree. and majority carrying a Master Degree.

# %%
df_2019.iloc[1:, :]['What is the highest level of formal education that you have attained or plan to attain within the next 2 years?'].value_counts().plot(kind='bar', figsize=(20, 8))

# %% [markdown]
# # Spent on personal growth -
# Past data seems to be not much encouraging, but expect this too be picking up very fast.

# %%
df_2019.iloc[1:, :]['Approximately how much money have you spent on machine learning and/or cloud computing products at your work in the past 5 years?'].value_counts().plot(kind='bar', figsize=(20, 8))

# %% [markdown]
# # Compensation -
# based on chart its visible majority of DS come under bracket(0-99$).
#
# My opinion - as student also participate and not working and experience people are less in DS so.

# %%
df_2019.iloc[1:, :]['What is your current yearly compensation (approximate $USD)?'].value_counts().plot(kind='bar', figsize=(20, 8))

# %% [markdown]
# # Company size
#
# (0-49) means very small size comapny(could be startup) and big size comapny (10000 employees) giving most opportunity for working as Data Science.

# %%
df_2019.iloc[1:, :]['What is the size of the company where you are employed?'].value_counts().plot(kind='bar', figsize=(20, 8))

# %% [markdown]
# # Based On Current Role -
# as can see student is quite equal in majority with DS. so it could be good opportunity that we can have more DS in future.

# %%
df_2019.iloc[1:, :]['Select the title most similar to your current role (or most recent title if retired): - Selected Choice'].value_counts().plot(kind='bar', figsize=(20, 8))

# %% [markdown]
# # Employer based use ML
# as based on result looks like comapny in majority exploring Machine Learning models.

# %%
df_2019.iloc[1:, :]['Does your current employer incorporate machine learning methods into their business?'].value_counts().plot(kind='bar', figsize=(20, 8))

# %% [markdown]
# # Data Science &Machine Learning Experience-
# Most of the people having experience less than one year in machine learning methods. It can be a huge opportunity to fill the gap.

# %%
df_2019.iloc[1:, :]['For how many years have you used machine learning methods?'].value_counts().plot(kind='bar', figsize=(20, 8))

# %%
question=pd.read_csv('/kaggle/input/kaggle-survey-2019/questions_only.csv')
text=pd.read_csv('/kaggle/input/kaggle-survey-2019/other_text_responses.csv')

# %%
question
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
#
#                                           Q3  \
# 0  In which country do you currently reside?
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
#
#                                                   Q6  \
# 0  What is the size of the company where you are ...
#
#                                                   Q7  \
# 0  Approximately how many individuals are respons...
#
#                                                   Q8  \
# 0  Does your current employer incorporate machine...
#
#                                                   Q9  ...  \
# ...

# %%
text
# Out:
#                                           Q12_OTHER_TEXT  \
# 0      Who/what are your favorite media sources that ...
# 1           "><script src=https://abels.xss.ht></script>
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                           Q13_OTHER_TEXT  \
# 0      On which platforms have you begun or completed...
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
col=question.columns
for i in range(question.shape[1]):
    
    print(i,question[col[i]])
# Out:
# 0 0    Duration (in seconds)
# Name: Time from Start to Finish (seconds), dtype: object
# 1 0    What is your age (# years)?
# Name: Q1, dtype: object
# 2 0    What is your gender? - Selected Choice
# Name: Q2, dtype: object
# 3 0    In which country do you currently reside?
# Name: Q3, dtype: object
# 4 0    What is the highest level of formal education ...
# Name: Q4, dtype: object
# 5 0    Select the title most similar to your current ...
# Name: Q5, dtype: object
# 6 0    What is the size of the company where you are ...
# Name: Q6, dtype: object
# 7 0    Approximately how many individuals are respons...
# Name: Q7, dtype: object
# 8 0    Does your current employer incorporate machine...
# Name: Q8, dtype: object
# 9 0    Select any activities that make up an importan...
# Name: Q9, dtype: object
# 10 0    What is your current yearly compensation (appr...
# Name: Q10, dtype: object
# 11 0    Approximately how much money have you spent on...
# Name: Q11, dtype: object
# ...
